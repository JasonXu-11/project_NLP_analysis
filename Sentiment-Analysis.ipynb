# %%
import pandas as pd
from nltk.tokenize import RegexpTokenizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# import file
stock = pd.read_csv('file/stockmarket.csv')
crypto = pd.read_csv('file/crypto.csv')

# %% [markdown]
# ### StockMarket subreddits

# %%
stock = stock[['title','subreddit']]

# %%
def tokenize(words):
    word = RegexpTokenizer(pattern=r'\w+').tokenize(words)
    return word

# %%
# Tokenize title text
stock['token'] = stock['title'].map(tokenize)
# Turn list into strs
stock['token'] = stock['token'].apply(', '.join)

# %%
stock
# Out:
#                                                  title    subreddit  \
# 0    I unveil the simple strategy that allows me an...  StockMarket
# 1                                         OPT up today  StockMarket
# 2                      Top 5 Crypto and how they work?  StockMarket
# 3    Citius: Halt For Superiority On The Horizon (N...  StockMarket
# 4                                              Testing  StockMarket
# ..                                                 ...          ...
# 995                                      New Ape HODLR  StockMarket
# 996                                              Karma  StockMarket
# 997  DONT LET THEM SHORT THIS MORGAGE REIT #IVR GRE...  StockMarket
# 998                        $HITI es empresa de FUTURO!  StockMarket
# 999  Will it look suspicious to have a different ba...  StockMarket
#
#                                                  token
# 0    I, unveil, the, simple, strategy, that, allows...
# 1                                       OPT, up, today
# 2                 Top, 5, Crypto, and, how, they, work
# 3    Citius, Halt, For, Superiority, On, The, Horiz...
# 4                                              Testing
# ..                                                 ...
# 995                                    New, Ape, HODLR
# 996                                              Karma
# 997  DONT, LET, THEM, SHORT, THIS, MORGAGE, REIT, I...
# 998                      HITI, es, empresa, de, FUTURO
# 999  Will, it, look, suspicious, to, have, a, diffe...
#
# [1000 rows x 3 columns]

# %%
# Instantiate sentimen analyzer
sia = SentimentIntensityAnalyzer()

# %%
# Generate polarity dictionaries
sia_dicts = [sia.polarity_scores(token) for token in stock['token']]

# Cast dictionaries to dataframe
sia_df = pd.DataFrame(sia_dicts)

# reset index
stock = stock.reset_index(drop = True)

# concat title and score
df_stock = pd.concat([stock, sia_df], axis = 1)

# %%
df_stock[['compound']].describe()
# Out:
#           compound
# count  1000.000000
# mean      0.120793
# std       0.336119
# min      -0.844200
# 25%       0.000000
# 50%       0.000000
# 75%       0.361375
# max       0.975700

# %%
def polar(num):
    if num > 0.05:
        return 'Positive'
    elif num < -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# %%
df_stock['polar'] = [polar(i) for i in df_stock['compound']]

# %%
df_stock
# Out:
#                                                  title    subreddit  \
# 0    I unveil the simple strategy that allows me an...  StockMarket
# 1                                         OPT up today  StockMarket
# 2                      Top 5 Crypto and how they work?  StockMarket
# 3    Citius: Halt For Superiority On The Horizon (N...  StockMarket
# 4                                              Testing  StockMarket
# ..                                                 ...          ...
# 995                                      New Ape HODLR  StockMarket
# 996                                              Karma  StockMarket
# 997  DONT LET THEM SHORT THIS MORGAGE REIT #IVR GRE...  StockMarket
# 998                        $HITI es empresa de FUTURO!  StockMarket
# 999  Will it look suspicious to have a different ba...  StockMarket
#
#                                                  token    neg    neu    pos  \
# 0    I, unveil, the, simple, strategy, that, allows...  0.000  0.804  0.196
# 1                                       OPT, up, today  0.000  1.000  0.000
# 2                 Top, 5, Crypto, and, how, they, work  0.000  0.769  0.231
# 3    Citius, Halt, For, Superiority, On, The, Horiz...  0.000  0.769  0.231
# 4                                              Testing  0.000  1.000  0.000
# ..                                                 ...    ...    ...    ...
# 995                                    New, Ape, HODLR  0.000  1.000  0.000
# 996                                              Karma  0.000  1.000  0.000
# 997  DONT, LET, THEM, SHORT, THIS, MORGAGE, REIT, I...  0.000  0.687  0.313
# 998                      HITI, es, empresa, de, FUTURO  0.000  1.000  0.000
# 999  Will, it, look, suspicious, to, have, a, diffe...  0.061  0.786  0.152
#
#      compound     polar
# 0      0.7456  Positive
# 1      0.0000   Neutral
# 2      0.2023  Positive
# 3      0.3400  Positive
# 4      0.0000   Neutral
# ..        ...       ...
# 995    0.0000   Neutral
# 996    0.0000   Neutral
# 997    0.6249  Positive
# 998    0.0000   Neutral
# 999    0.4019  Positive
#
# [1000 rows x 8 columns]

# %%
df_stock['polar'].value_counts(normalize=True)
# Out:
# Neutral     0.521
# Positive    0.351
# Negative    0.128
# Name: polar, dtype: float64

# %% [markdown]
# ### CryptoCurrency subreddits

# %%
# build a dataframe with title and subreddit
crypto = crypto[['title','subreddit']]

# %%
# Tokenize title text
crypto['token'] = crypto['title'].map(tokenize)
# Turn list into strs
crypto['token'] = crypto['token'].apply(', '.join)

# %%
# Generate polarity dictionaries
sia_dicts = [sia.polarity_scores(token) for token in crypto['token']]

# Cast dictionaries to dataframe
sia_df = pd.DataFrame(sia_dicts)

# reset index
stock = stock.reset_index(drop = True)

# concat title and score
df_crypto = pd.concat([crypto, sia_df], axis = 1)

# %%
df_stock[['compound']].describe()
# Out:
#           compound
# count  1000.000000
# mean      0.082168
# std       0.308086
# min      -0.980100
# 25%       0.000000
# 50%       0.000000
# 75%       0.273200
# max       0.940300

# %%
df_crypto['polar'] = [polar(i) for i in df_crypto['compound']]

# %%
df_crypto['polar'].value_counts(normalize=True)
# Out:
# Neutral     0.550
# Positive    0.314
# Negative    0.136
# Name: polar, dtype: float64

# %% [markdown]
# ### The proportion of positive and negative posts are highly similar. Both subreddits may have very similar user groups and users share very similar thought for writing titles.
